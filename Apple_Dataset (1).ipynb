# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_1 = pd.read_csv('/Users/yashgupta/Downloads/Apple_Sales_prev.csv')

# %%
data_1
# Out:
#                                 Product Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       51900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       72000
# ...

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Product Name         62 non-null     object
#  1   Product URL          62 non-null     object
#  2   Brand                62 non-null     object
#  3   Sale Price           62 non-null     int64
#  4   Mrp                  62 non-null     int64
#  5   Discount Percentage  62 non-null     float64
#  6   Number Of Ratings    62 non-null     int64
#  7   Units Sold           62 non-null     int64
#  8   Upc                  62 non-null     object
#  9   Star Rating          62 non-null     float64
#  10  Ram                  62 non-null     object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 5.5+ KB

# %%
data_1.head()
# Out:
#                                Product Name  \
# 0         APPLE iPhone 8 Plus (Gold, 64 GB)
# 1  APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2      APPLE iPhone 8 Plus (Silver, 256 GB)
# 3           APPLE iPhone 8 (Silver, 256 GB)
# 4             APPLE iPhone 8 (Gold, 256 GB)
#
#                                          Product URL  Brand  Sale Price  \
# 0  https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       51900
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3  https://www.flipkart.com/apple-iphone-8-silver...  Apple       72000
# 4  https://www.flipkart.com/apple-iphone-8-gold-2...  Apple       77000
#
#      Mrp  Discount Percentage  Number Of Ratings  Units Sold  \
# 0  54900                  5.0               3431         286
# 1  89900                  5.5               3431         242
# 2  89900                  5.5               3431         289
# ...

# %%
data_1.tail()
# Out:
#                        Product Name  \
# 57   APPLE iPhone SE (Black, 64 GB)
# 58  APPLE iPhone 11 (Purple, 64 GB)
# 59   APPLE iPhone 11 (White, 64 GB)
# 60   APPLE iPhone 11 (Black, 64 GB)
# 61     APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 57  https://www.flipkart.com/apple-iphone-se-black...  Apple       32999
# 58  https://www.flipkart.com/apple-iphone-11-purpl...  Apple       51999
# 59  https://www.flipkart.com/apple-iphone-11-white...  Apple       51999
# 60  https://www.flipkart.com/apple-iphone-11-black...  Apple       51999
# 61  https://www.flipkart.com/apple-iphone-11-red-6...  Apple       51999
#
#       Mrp  Discount Percentage  Number Of Ratings  Units Sold  \
# 57  39900                 17.0              95909        7111
# 58  58900                 11.0              43470        2381
# 59  58900                 11.0              43470        3001
# ...

# %%
data_1.isnull()
# Out:
#     Product Name  Product URL  Brand  Sale Price    Mrp  Discount Percentage  \
# 0          False        False  False       False  False                False
# 1          False        False  False       False  False                False
# 2          False        False  False       False  False                False
# 3          False        False  False       False  False                False
# 4          False        False  False       False  False                False
# ..           ...          ...    ...         ...    ...                  ...
# 57         False        False  False       False  False                False
# 58         False        False  False       False  False                False
# 59         False        False  False       False  False                False
# 60         False        False  False       False  False                False
# 61         False        False  False       False  False                False
#
# ...

# %%
data_1.max()
# Out:
# Product Name           Apple iPhone XR (White, 128 GB) (Includes EarP...
# Product URL            https://www.flipkart.com/apple-iphone-xs-max-s...
# Brand                                                              Apple
# Sale Price                                                        155900
# Mrp                                                               165900
# Discount Percentage                                                 17.0
# Number Of Ratings                                                  95909
# Units Sold                                                          7823
# Upc                                                     MOBFWQ6BYYV3FCU7
# Star Rating                                                          4.7
# Ram                                                                 6 GB
# dtype: object

# %%
data_1.head(7).plot(x='Product Name', y='Units Sold', kind="bar", figsize=(7,7), color="red")
plt.xticks(fontsize=7)
plt.xlabel("Product Name")
plt.ylabel("Units Sold")
plt.title("Units of iPhones sold")
# Out:
# Text(0.5, 1.0, 'Units of iPhones sold')

# %%
data_1.iloc[8:14].plot(x='Product Name', y='Units Sold', kind="bar", figsize=(7,7), color="blue")
plt.xticks(fontsize=7)
plt.xlabel("Product Name")
plt.ylabel("Units Sold")
plt.title("Units of iPhones sold")
# Out:
# Text(0.5, 1.0, 'Units of iPhones sold')

# %%
data_1.iloc[15:24].plot(x='Product Name', y='Units Sold', kind="bar", figsize=(7,7), color="green")
plt.xticks(fontsize=7)
plt.xlabel("Product Name")
plt.ylabel("Units Sold")
plt.title("Units of iPhones sold")
# Out:
# Text(0.5, 1.0, 'Units of iPhones sold')

# %%
data_1.iloc[25:41].plot(x='Product Name', y='Units Sold', kind="bar", figsize=(7,7), color="yellow")
plt.xticks(fontsize=7)
plt.xlabel("Product Name")
plt.ylabel("Units Sold")
plt.title("Units of iPhones sold")
# Out:
# Text(0.5, 1.0, 'Units of iPhones sold')

# %%
data_1.iloc[41:50].plot(x='Product Name', y='Units Sold', kind="bar", figsize=(7,7), color="orange")
plt.xticks(fontsize=7)
plt.xlabel("Product Name")
plt.ylabel("Units Sold")
plt.title("Units of iPhones sold")
# Out:
# Text(0.5, 1.0, 'Units of iPhones sold')

# %%
data_1.iloc[50:62].plot(x='Product Name', y='Units Sold', kind="bar", figsize=(7,7), color="pink")
plt.xticks(fontsize=7)
plt.xlabel("Product Name")
plt.ylabel("Units Sold")
plt.title("Units of iPhones sold")
# Out:
# Text(0.5, 1.0, 'Units of iPhones sold')

# %%
x = data_1.head(7)['Product Name']
y = data_1.head(7)['Discount Percentage']
plt.pie(y, labels = x, radius = 3, autopct='%1.1f%%')
plt.legend(loc="best")
plt.xticks(rotation=30)
plt.title('Discounts offered on iPhones')
plt.show()

# %%
x = data_1.iloc[8:14]['Product Name']
y = data_1.iloc[8:14]['Discount Percentage']
plt.pie(y, labels = x, radius = 2.9, autopct='%1.1f%%')
plt.legend(loc="best")
plt.xticks(rotation=30)
plt.title('Discounts offered on iPhones')
plt.show()

# %%
x = data_1.iloc[15:24]['Product Name']
y = data_1.iloc[15:24]['Discount Percentage']
plt.pie(y, labels = x, radius = 3.6, autopct='%1.1f%%')
plt.legend(loc="best")
plt.xticks(rotation=30)
plt.title('Discounts offered on iPhones')
plt.show()

# %%
x = data_1.iloc[25:41]['Product Name']
y = data_1.iloc[25:41]['Discount Percentage']
plt.pie(y, labels = x, radius = 4, autopct='%1.1f%%')
plt.legend(loc="best")
plt.xticks(rotation=30)
plt.title('Discounts offered on iPhones')
plt.show()

# %%
x = data_1.iloc[41:50]['Product Name']
y = data_1.iloc[41:50]['Discount Percentage']
plt.pie(y, labels = x, radius = 2.6, autopct='%1.1f%%')
plt.legend(loc="best")
plt.xticks(rotation=30)
plt.title('Discounts offered on iPhones')
plt.show()

# %%
x = data_1.iloc[50:62]['Product Name']
y = data_1.iloc[50:62]['Discount Percentage']
plt.pie(y, labels = x, radius = 2.8, autopct='%1.1f%%')
plt.legend(loc="best")
plt.xticks(rotation=30)
plt.title('Discounts offered on iPhones')
plt.show()

# %%
x = data_1['Product Name']
y = data_1['Sale Price']
z = data_1['Mrp']
plt.figure(figsize=(28,9))
plt.scatter(x, z, label = 'Maximum Retail Price')
plt.scatter(x, y, label = 'Sales Price')
plt.legend()
plt.xticks(rotation = 90)
plt.show()

# %%
data_2 = pd.read_csv('/Users/yashgupta/Downloads/Salesdata_2.csv')

# %%
data_2
# Out:
#                                 Product Name  \
# 0          APPLE iPhone 8 Plus (Gold, 64 GB)
# 1   APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2       APPLE iPhone 8 Plus (Silver, 256 GB)
# 3            APPLE iPhone 8 (Silver, 256 GB)
# 4              APPLE iPhone 8 (Gold, 256 GB)
# ..                                       ...
# 57            APPLE iPhone SE (Black, 64 GB)
# 58           APPLE iPhone 11 (Purple, 64 GB)
# 59            APPLE iPhone 11 (White, 64 GB)
# 60            APPLE iPhone 11 (Black, 64 GB)
# 61              APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 0   https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2   https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3   https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# ...

# %%
data_2.head()
# Out:
#                                Product Name  \
# 0         APPLE iPhone 8 Plus (Gold, 64 GB)
# 1  APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2      APPLE iPhone 8 Plus (Silver, 256 GB)
# 3           APPLE iPhone 8 (Silver, 256 GB)
# 4             APPLE iPhone 8 (Gold, 256 GB)
#
#                                          Product URL  Brand  Sale Price  \
# 0  https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3  https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# 4  https://www.flipkart.com/apple-iphone-8-gold-2...  Apple       77000
#
#      Mrp  Discount Percentage  Number Of Ratings  Units Sold  \
# 0  49900                    0               3431         356
# 1  84900                    0               3431         356
# 2  84900                    0               3431         356
# ...

# %%
data_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Product Name         62 non-null     object
#  1   Product URL          62 non-null     object
#  2   Brand                62 non-null     object
#  3   Sale Price           62 non-null     int64
#  4   Mrp                  62 non-null     int64
#  5   Discount Percentage  62 non-null     int64
#  6   Number Of Ratings    62 non-null     int64
#  7   Units Sold           62 non-null     int64
#  8   Upc                  62 non-null     object
#  9   Star Rating          62 non-null     float64
#  10  Ram                  62 non-null     object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 5.5+ KB

# %%
data_2.isnull()
# Out:
#     Product Name  Product URL  Brand  Sale Price    Mrp  Discount Percentage  \
# 0          False        False  False       False  False                False
# 1          False        False  False       False  False                False
# 2          False        False  False       False  False                False
# 3          False        False  False       False  False                False
# 4          False        False  False       False  False                False
# ..           ...          ...    ...         ...    ...                  ...
# 57         False        False  False       False  False                False
# 58         False        False  False       False  False                False
# 59         False        False  False       False  False                False
# 60         False        False  False       False  False                False
# 61         False        False  False       False  False                False
#
# ...

# %%
data_2.tail(10)
# Out:
#                        Product Name  \
# 52   APPLE iPhone SE (White, 64 GB)
# 53  APPLE iPhone SE (Black, 128 GB)
# 54  APPLE iPhone SE (White, 128 GB)
# 55    APPLE iPhone SE (Red, 128 GB)
# 56  APPLE iPhone 11 (Black, 128 GB)
# 57   APPLE iPhone SE (Black, 64 GB)
# 58  APPLE iPhone 11 (Purple, 64 GB)
# 59   APPLE iPhone 11 (White, 64 GB)
# 60   APPLE iPhone 11 (Black, 64 GB)
# 61     APPLE iPhone 11 (Red, 64 GB)
#
#                                           Product URL  Brand  Sale Price  \
# 52  https://www.flipkart.com/apple-iphone-se-white...  Apple       29999
# 53  https://www.flipkart.com/apple-iphone-se-black...  Apple       34999
# 54  https://www.flipkart.com/apple-iphone-se-white...  Apple       34999
# 55  https://www.flipkart.com/apple-iphone-se-red-1...  Apple       34999
# 56  https://www.flipkart.com/apple-iphone-11-black...  Apple       54999
# 57  https://www.flipkart.com/apple-iphone-se-black...  Apple       29999
# ...

# %%
data_2.max()
# Out:
# Product Name           Apple iPhone XR (White, 128 GB) (Includes EarP...
# Product URL            https://www.flipkart.com/apple-iphone-xs-max-s...
# Brand                                                              Apple
# Sale Price                                                        140900
# Mrp                                                               149900
# Discount Percentage                                                   29
# Number Of Ratings                                                  95909
# Units Sold                                                          8161
# Upc                                                     MOBFWQ6BYYV3FCU7
# Star Rating                                                          4.7
# Ram                                                                 6 GB
# dtype: object

# %%
data_2.head(7).plot(x='Product Name', y='Units Sold', kind="bar", figsize=(7,7), color="red")
plt.xticks(fontsize=7)
plt.xlabel("Product Name")
plt.ylabel("Units Sold")
plt.title("Units of iPhones sold")
# Out:
# Text(0.5, 1.0, 'Units of iPhones sold')

# %%
data_2.iloc[8:14].plot(x='Product Name', y='Units Sold', kind="bar", figsize=(7,7), color="blue")
plt.xticks(fontsize=7)
plt.xlabel("Product Name")
plt.ylabel("Units Sold")
plt.title("Units of iPhones sold")
# Out:
# Text(0.5, 1.0, 'Units of iPhones sold')

# %%
data_2.iloc[15:24].plot(x='Product Name', y='Units Sold', kind="bar", figsize=(7,7), color="green")
plt.xticks(fontsize=7)
plt.xlabel("Product Name")
plt.ylabel("Units Sold")
plt.title("Units of iPhones sold")
# Out:
# Text(0.5, 1.0, 'Units of iPhones sold')

# %%
data_2.iloc[25:41].plot(x='Product Name', y='Units Sold', kind="bar", figsize=(7,7), color="yellow")
plt.xticks(fontsize=7)
plt.xlabel("Product Name")
plt.ylabel("Units Sold")
plt.title("Units of iPhones sold")
# Out:
# Text(0.5, 1.0, 'Units of iPhones sold')

# %%
data_2.iloc[41:50].plot(x='Product Name', y='Units Sold', kind="bar", figsize=(7,7), color="orange")
plt.xticks(fontsize=7)
plt.xlabel("Product Name")
plt.ylabel("Units Sold")
plt.title("Units of iPhones sold")
# Out:
# Text(0.5, 1.0, 'Units of iPhones sold')

# %%
data_2.iloc[50:62].plot(x='Product Name', y='Units Sold', kind="bar", figsize=(7,7), color="pink")
plt.xticks(fontsize=7)
plt.xlabel("Product Name")
plt.ylabel("Units Sold")
plt.title("Units of iPhones sold")
# Out:
# Text(0.5, 1.0, 'Units of iPhones sold')

# %%
x = data_2.iloc[9:14]['Product Name']
y = data_2.iloc[9:14]['Discount Percentage']
plt.pie(y, labels = x, radius = 2.9, autopct='%1.1f%%')
plt.legend(loc="best")
plt.xticks(rotation=30)
plt.title('Discounts offered on iPhones')
plt.show()

# %%
x = data_2.iloc[14:24]['Product Name']
y = data_2.iloc[14:24]['Discount Percentage']
plt.pie(y, labels = x, radius = 3.8, autopct='%1.1f%%')
plt.legend(loc="best")
plt.xticks(rotation=30)
plt.title('Discounts offered on iPhones')
plt.show()

# %%
x = data_2.iloc[25:41]['Product Name']
y = data_2.iloc[25:41]['Discount Percentage']
plt.pie(y, labels = x, radius = 2.9, autopct='%1.1f%%')
plt.legend(loc="best")
plt.xticks(rotation=30)
plt.title('Discounts offered on iPhones')
plt.show()

# %%
x = data_2.iloc[41:50]['Product Name']
y = data_2.iloc[41:50]['Discount Percentage']
plt.pie(y, labels = x, radius = 2.9, autopct='%1.1f%%')
plt.legend(loc="best")
plt.xticks(rotation=30)
plt.title('Discounts offered on iPhones')
plt.show()

# %%
x = data_2.iloc[50:62]['Product Name']
y = data_2.iloc[50:62]['Discount Percentage']
plt.pie(y, labels = x, radius = 2.9, autopct='%1.1f%%')
plt.legend(loc="best")
plt.xticks(rotation=30)
plt.title('Discounts offered on iPhones')
plt.show()

# %%
x = data_2['Product Name']
y = data_2['Sale Price']
z = data_2['Mrp']
plt.figure(figsize=(28,9))
plt.scatter(x, z, label = 'Maximum Retail Price')
plt.scatter(x, y, label = 'Sales Price')
plt.legend()
plt.xticks(rotation = 90)
plt.show()

# %%
growth = pd.read_csv('/Users/yashgupta/Downloads/Growth_1.csv')

# %%
growth
# Out:
#    Category  iPhone  YOY growth
# 0     Q1/11   0.817         NaN
# 1     Q2/11   2.483       22.55
# 2     Q3/11   4.406       23.02
# 3     Q4/11   2.940       28.78
# 4     Q1/12   2.427       29.06
# 5     Q2/12   3.060       30.54
# 6     Q3/12   4.606       32.54
# 7     Q4/12   5.578       38.73
# 8     Q1/13   5.445       36.35
# 9     Q2/13   5.334       35.31
# 10    Q3/13   8.822       34.53
# 11    Q4/13  10.239       32.56
# 12    Q1/14  12.053       29.36
# 13    Q2/14  13.102       24.63
# 14    Q3/14  10.604       20.20
# 15    Q4/14  23.950       39.91
# 16    Q1/15  22.276       38.82
# 17    Q2/15  17.821       32.75
# 18    Q3/15  19.645       35.97
# 19    Q4/15  16.660       31.02
# 20    Q1/16  22.955       37.05
# 21    Q2/16  21.154       36.75

# %%
growth.dropna()
# Out:
#    Category  iPhone  YOY growth
# 1     Q2/11   2.483       22.55
# 2     Q3/11   4.406       23.02
# 3     Q4/11   2.940       28.78
# 4     Q1/12   2.427       29.06
# 5     Q2/12   3.060       30.54
# 6     Q3/12   4.606       32.54
# 7     Q4/12   5.578       38.73
# 8     Q1/13   5.445       36.35
# 9     Q2/13   5.334       35.31
# 10    Q3/13   8.822       34.53
# 11    Q4/13  10.239       32.56
# 12    Q1/14  12.053       29.36
# 13    Q2/14  13.102       24.63
# 14    Q3/14  10.604       20.20
# 15    Q4/14  23.950       39.91
# 16    Q1/15  22.276       38.82
# 17    Q2/15  17.821       32.75
# 18    Q3/15  19.645       35.97
# 19    Q4/15  16.660       31.02
# 20    Q1/16  22.955       37.05
# 21    Q2/16  21.154       36.75

# %%
x = growth['Category']
y = growth['iPhone']
z = growth['YOY growth']
plt.figure(figsize=(25,10))
display(plt.plot(x,z,label = 'year on year Growth in iPhone Revenue (in million$)'))
display(plt.plot(x,y,label = 'iPhone sales (in thousands)',linestyle = '--'))
plt.legend()

# %%
growth_2 = pd.read_csv('/Users/yashgupta/Downloads/Growth_2.csv')

# %%
growth_2
# Out:
#    Category  iPhone  YOY growth
# 0     Q1/18  19.510       35.21
# 1     Q2/18  32.498       41.99
# 2     Q3/18  26.064       37.54
# 3     Q4/18  19.751       35.80
# 4     Q1/19  23.678       38.36
# 5     Q2/19  51.182       62.49
# 6     Q3/19  40.282       54.55
# 7     Q4/19  31.368       40.82
# 8     Q1/20  32.209       43.03
# 9     Q2/20  51.635       63.89
# 10    Q3/20  32.857       40.43
# 11    Q4/20  24.048       32.34
# 12    Q1/21  29.451       39.64
# 13    Q2/21  31.743       40.87
# 14    Q3/21  37.512       51.54
# 15    Q4/21  42.319       56.42
# 16    Q1/22  59.421       68.43
# 17    Q2/22  62.056       73.86
# 18    Q3/22  68.934       81.94
# 19    Q4/22  73.417       87.42

# %%
x = growth_2['Category']
y = growth_2['iPhone']
z = growth_2['YOY growth']
plt.figure(figsize=(25,10))
display(plt.plot(x,z,label = 'year On year Growth in iPhone Revenue (in million$)'))
display(plt.plot(x,y,label = 'iPhone sales (in thousands)',linestyle = '--'))
plt.legend()
